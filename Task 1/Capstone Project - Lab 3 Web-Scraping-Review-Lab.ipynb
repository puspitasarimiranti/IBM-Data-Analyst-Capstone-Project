# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a webpage
# * Scrape all image URLs from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a webpage

# %% [markdown]
# Download the contents of the webpage

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/case-studies/pfizer?lnk=hpls1us
# https://www.ibm.com/solutions/hybrid-cloud?lnk=hpls2us
# https://www.ibm.com/think/podcasts/smart-talks/creating-smarter-business-with-ai-and-quantum?lnk=hprc1us
# https://www.ibm.com/thought-leadership/institute-business-value/report/ai-infrastructure?lnk=hprc2us
# https://newsroom.ibm.com/2025-10-07-2025-ibm-and-anthropic-partner-to-advance-enterprise-software-development-with-proven-security-and-governance?lnk=hprc3us
# https://www.ibm.com/account/reg/signup?formid=urx-54070&lnk=hprc4us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs1us
# https://www.ibm.com/case-studies/us-open?lnk=hpcs3us
# https://www.ibm.com/case-studies/avid-solutions-international?lnk=hpcs4us
# https://www.ibm.com/case-studies/ufc?lnk=hpcs2us
# https://ibmzday.bemyapp.com/?lnk=hppr1us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/solutions/ai-agents?lnk=hpfp2us
# https://www.ibm.com/solutions/data-and-ai?lnk=hpfp3us
# https://www.ibm.com/solutions/automation?lnk=hpfp4us
# https://www.ibm.com/solutions/hybrid-cloud?lnk=hpfp5us
# https://www.ibm.com/solutions/ai-models?lnk=hpfp6us
# https://www.ibm.com/solutions/analytics?lnk=hpfp7us
# https://www.ibm.com/solutions/security?lnk=hpfp8us
# https://www.ibm.com/consulting?lnk=hpfp9us
# https://www.ibm.com/about?lnk=hpii1us
# https://www.ibm.com/history?lnk=hpii1us
# https://research.ibm.com?lnk=hpii1us
# https://www.ibm.com/quantum?lnk=hpii1us
# https://www.ibm.com/careers?lnk=hpii1us
# https://skillsbuild.org?lnk=hpii1us
# https://newsroom.ibm.com/2025-11-04-ibm-fusion-delivers-pioneering-implementation-of-nvidia-ai-data-platform-for-agentic-ai
# https://newsroom.ibm.com/2025-10-28-Two-thirds-of-surveyed-enterprises-in-EMEA-report-significant-productivity-gains-from-AI,-finds-new-IBM-study
# https://newsroom.ibm.com/2025-10-28-IBM-Report-Two-Thirds-of-UK-Firms-Gain-from-AI-Reskilling-Key-to-Unlocking-Greater-Productivity
# https://newsroom.ibm.com/ibm-digital-asset-haven
# https://newsroom.ibm.com/2025-10-22-IBM-RELEASES-THIRD-QUARTER-RESULTS
# https://newsroom.ibm.com/2025-10-29-ibm-announces-defense-focused-ai-model-to-accelerate-mission-planning-and-decision-support
# https://newsroom.ibm.com/2025-10-20-ibm-and-groq-partner-to-accelerate-enterprise-ai-deployment-with-speed-and-scale

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/IBM-2020-AR-Arvind_1800x2400_1b_crop?ts=1761751999534&dpr=off
# https://assets.ibm.com/is/image/ibm/watsonxdata_technicalillustration_crop?ts=1761752014626&dpr=off
# https://assets.ibm.com/is/image/ibm/antorpihc?ts=1761752021585&dpr=off
# https://assets.ibm.com/is/image/ibm/trailv2_1-1?ts=1761752043078&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_ferrari_video_thumb_01?ts=1761752057069&dpr=off
# https://assets.ibm.com/is/image/ibm/us-open-crowd-court?ts=1761752057881&dpr=off
# https://assets.ibm.com/is/image/ibm/watsonx-orchestrate_avid-solutions_dco-native?ts=1761752058639&dpr=off
# https://assets.ibm.com/is/image/ibm/1731592760476?ts=1761752059498&dpr=off
# https://assets.ibm.com/is/image/ibm/z-secure-leadspace-z17?ts=1761752044350&dpr=off
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1761752055699&dpr=off

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below URL contains a html table with data about colors and color codes.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a website, you need to examine the contents, and the way data is organized on the website. Open the above URL in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(URL).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %% [markdown]
# # Get all rows from the table

# %%
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# <!--
# ## Change Log
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-10-29  | 0.2  | Madhusudhan Moole |  Updated lab |
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
