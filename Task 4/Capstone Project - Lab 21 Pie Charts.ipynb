# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 176.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 203.4 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 137.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 170.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 168.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-11-21 04:49:44--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# 169.63.118.104ourses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)...
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  66.2MB/s    in 2.3s
#
# 2025-11-21 04:49:46 (66.2 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# ...

# %%
df.info('ResponseId')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Data columns (total 114 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    ResponseId                      int64
#  1    MainBranch                      object
#  2    Age                             object
#  3    Employment                      object
#  4    RemoteWork                      object
#  5    Check                           object
#  6    CodingActivities                object
#  7    EdLevel                         object
#  8    LearnCode                       object
#  9    LearnCodeOnline                 object
#  10   TechDoc                         object
#  11   YearsCode                       object
#  12   YearsCodePro                    object
#  13   DevType                         object
#  14   OrgSize                         object
#  15   PurchaseInfluence               object
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
#If the data is collected as semi-colon separated strings in a single column (common in SO surveys),
#Split and explode the entries first to count individual databases.
#Example if entries look like: 'MySQL;PostgreSQL'
if df['DatabaseWantToWorkWith'].dtype == 'object' and df['DatabaseWantToWorkWith'].str.contains(';').any():
    df['DatabaseWantToWorkWith'] = df['DatabaseWantToWorkWith'].str.split(';')
    df = df.explode('DatabaseWantToWorkWith')
    # Strip any potential leading/trailing whitespace after splitting
    df['DatabaseWantToWorkWith'] = df['DatabaseWantToWorkWith'].str.strip()


#Count the occurrences of each database
# value_counts() is the simplest way to count unique values in a Series
database_counts = df['DatabaseWantToWorkWith'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_databases = database_counts.head(top_n)

#create pie chart
labels = top_databases.index
sizes = top_databases.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Desired Databases (Want To Work With)')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
#Check unique value
print('\nThere are', df['DevType'].nunique(), 'unique DevType values in the survey:')
print(df['DevType'].value_counts())
# Out:
# There are 34 unique DevType values in the survey:
# DevType
# Developer, full-stack                            48733
# Developer, back-end                              26304
# Student                                          10158
# Developer, front-end                              5949
# Other (please specify):                           5312
# Developer, desktop or enterprise applications     4836
# Developer, mobile                                 3910
# Engineering manager                               3465
# Data engineer                                     3353
# DevOps specialist                                 2691
# Data scientist or machine learning specialist     2548
# Senior Executive (C-Suite, VP, etc.)              2361
# Developer, embedded applications or devices       2317
# Academic researcher                               2157
# Research & Development role                       1938
# Cloud infrastructure engineer                     1833
# ...

# %%
#Count the occurrences of each database
#value_counts() is the simplest way to count unique values in a Series
dev_counts = df['DevType'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_dev = dev_counts.head(top_n)

#create pie chart
labels = top_dev.index
sizes = top_dev.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Developer Type')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
#Check unique value
print('\nThere are', df['OpSysProfessional use'].nunique(), 'unique OpSysProfessional values in the survey:')
print(df['OpSysProfessional use'].value_counts())
# Out:
# There are 2032 unique OpSysProfessional values in the survey:
# OpSysProfessional use
# Windows                                                                    21200
# MacOS                                                                      18363
# Ubuntu                                                                      8067
# Windows;Windows Subsystem for Linux (WSL)                                   7110
# Ubuntu;Windows;Windows Subsystem for Linux (WSL)                            4676
#                                                                            ...
# Arch;BSD;Ubuntu;Windows;Windows Subsystem for Linux (WSL)                      1
# Debian;iPadOS;Windows                                                          1
# Android;Arch;Other Linux-based;Ubuntu;Windows Subsystem for Linux (WSL)        1
# AIX;Other Linux-based;Red Hat;Windows;Other (please specify):                  1
# Arch;Cygwin;MacOS;Ubuntu;Windows Subsystem for Linux (WSL)                     1
# ...

# %%
#If the data is collected as semi-colon separated strings in a single column,
#Split and explode the entries first to count individual operating system.
#Example if entries look like: 'Debian;iPadOS;Windows'
if df['OpSysProfessional use'].dtype == 'object' and df['OpSysProfessional use'].str.contains(';').any():
    df['OpSysProfessional use'] = df['OpSysProfessional use'].str.split(';')
    df = df.explode('OpSysProfessional use')
    # Strip any potential leading/trailing whitespace after splitting
    df['OpSysProfessional use'] = df['OpSysProfessional use'].str.strip()


#Count the occurrences of each opsys
# value_counts() is the simplest way to count unique values in a Series
opsys_counts = df['OpSysProfessional use'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_opsys = opsys_counts.head(top_n)

#create pie chart
labels = top_opsys.index
sizes = top_opsys.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Desired Operating System')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
#Check unique value
print('\nThere are', df['LanguageHaveWorkedWith'].nunique(), 'unique LanguageHaveWorkedWith values in the survey:')
print(df['LanguageHaveWorkedWith'].value_counts())
# Out:
# There are 23864 unique LanguageHaveWorkedWith values in the survey:
# LanguageHaveWorkedWith
# Ada;Apex;Assembly;Bash/Shell (all shells);C;C#;C++;Clojure;Cobol;Crystal;Dart;Delphi;Elixir;Erlang;F#;Fortran;GDScript;Go;Groovy;Haskell;HTML/CSS;Java;JavaScript;Julia;Kotlin;Lisp;Lua;MATLAB;MicroPython;Nim;Objective-C;OCaml;Perl;PHP;PowerShell;Prolog;Python;R;Ruby;Rust;Scala;Solidity;SQL;Swift;TypeScript;VBA;Visual Basic (.Net);Zephyr;Zig    8695
# HTML/CSS;JavaScript;TypeScript                                                                                                                                                                                                                                                                                                                           2929
# ...

# %%
#If the data is collected as semi-colon separated strings in a single column,
#Split and explode the entries first to count individual language.
#Example if entries look like: 'Dart;HTML/CSS;JavaScript;PowerShell;Python'
if df['LanguageHaveWorkedWith'].dtype == 'object' and df['LanguageHaveWorkedWith'].str.contains(';').any():
    df['LanguageHaveWorkedWith'] = df['LanguageHaveWorkedWith'].str.split(';')
    df = df.explode('LanguageHaveWorkedWith')
    # Strip any potential leading/trailing whitespace after splitting
    df['LanguageHaveWorkedWith'] = df['LanguageHaveWorkedWith'].str.strip()

#Count the occurrences of each database
# value_counts() is the simplest way to count unique values in a Series
language_counts = df['LanguageHaveWorkedWith'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_language = language_counts.head(top_n)

#create pie chart
labels = top_language.index
sizes = top_language.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Desired Language')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here

# %%
#Check unique value
print('\nThere are', df['NEWCollabToolsHaveWorkedWith'].nunique(), 'unique NEWCollabToolsHaveWorkedWith values in the survey:')
print(df['NEWCollabToolsHaveWorkedWith'].value_counts())
# Out:
# There are 14168 unique NEWCollabToolsHaveWorkedWith values in the survey:
# NEWCollabToolsHaveWorkedWith
# Visual Studio Code                                                             24359
# Visual Studio;Visual Studio Code                                               11866
# Notepad++;Visual Studio;Visual Studio Code                                      7936
# IntelliJ IDEA;Visual Studio Code                                                5342
# Vim;Visual Studio Code                                                          5056
#                                                                                ...
# CLion;Qt Creator;Sublime Text;Vim;Visual Studio                                    1
# Android Studio;CLion;Notepad++;PyCharm;Vim;Visual Studio;Visual Studio Code        1
# IPython;Notepad++;PyCharm;Visual Studio Code                                       1
# Nano;PyCharm;Vim;WebStorm                                                          1
# ...

# %%
#If the data is collected as semi-colon separated strings in a single column,
#Split and explode the entries first to count individual tools.
#Example if entries look like: 'Nano;PyCharm;Vim;WebStorm'
if df['NEWCollabToolsHaveWorkedWith'].dtype == 'object' and df['NEWCollabToolsHaveWorkedWith'].str.contains(';').any():
    df['NEWCollabToolsHaveWorkedWith'] = df['NEWCollabToolsHaveWorkedWith'].str.split(';')
    df = df.explode('NEWCollabToolsHaveWorkedWith')
    # Strip any potential leading/trailing whitespace after splitting
    df['NEWCollabToolsHaveWorkedWith'] = df['NEWCollabToolsHaveWorkedWith'].str.strip()


#Count the occurrences of each tools
# value_counts() is the simplest way to count unique values in a Series
tools_counts = df['NEWCollabToolsHaveWorkedWith'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_tools = tools_counts.head(top_n)

#create pie chart
labels = top_tools.index
sizes = top_tools.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Desired Tools')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
#Check unique value
print('\nThere are', df['LanguageAdmired'].nunique(), 'unique LanguageAdmired values in the survey:')
print(df['LanguageAdmired'].value_counts())
# Out:
# There are 12335 unique LanguageAdmired values in the survey:
# LanguageAdmired
# Ada;Apex;Assembly;Bash/Shell (all shells);C;C#;C++;Clojure;Cobol;Crystal;Dart;Delphi;Elixir;Erlang;F#;Fortran;GDScript;Go;Groovy;Haskell;HTML/CSS;Java;JavaScript;Julia;Kotlin;Lisp;Lua;MATLAB;MicroPython;Nim;Objective-C;OCaml;Perl;PHP;PowerShell;Prolog;Python;R;Ruby;Rust;Scala;Solidity;SQL;Swift;TypeScript;VBA;Visual Basic (.Net);Zephyr;Zig    21560
# Python                                                                                                                                                                                                                                                                                                                                                   13118
# ...

# %%
#If the data is collected as semi-colon separated strings in a single column,
#Split and explode the entries first to count language.
#Example if entries look like: 'HTML/CSS;JavaScript;TypeScript'
if df['LanguageAdmired'].dtype == 'object' and df['LanguageAdmired'].str.contains(';').any():
    df['LanguageAdmired'] = df['LanguageAdmired'].str.split(';')
    df = df.explode('LanguageAdmired')
    # Strip any potential leading/trailing whitespace after splitting
    df['LanguageAdmired'] = df['LanguageAdmired'].str.strip()


#Count the occurrences of each language
# value_counts() is the simplest way to count unique values in a Series
languageadmired_counts = df['LanguageAdmired'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_languageadmired = languageadmired_counts.head(top_n)

#create pie chart
labels = top_languageadmired.index
sizes = top_languageadmired.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Admired Language')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
#Check unique value
print('\nThere are', df['AIToolCurrently Using'].nunique(), 'unique AIToolCurrently values in the survey:')
print(df['AIToolCurrently Using'].value_counts())
# Out:
# There are 1310 unique AIToolCurrently values in the survey:
# AIToolCurrently Using
# Writing code;Debugging and getting help;Search for answers                                                                                                                                                                                                          6329
# Writing code                                                                                                                                                                                                                                                        6011
# Writing code;Search for answers                                                                                                                                                                                                                                     4890
# ...

# %%
#If the data is collected as semi-colon separated strings in a single column,
#Split and explode the entries first to count AI Tools.
#Example if entries look like: 'Writing code;Search for answers'
if df['AIToolCurrently Using'].dtype == 'object' and df['AIToolCurrently Using'].str.contains(';').any():
    df['AIToolCurrently Using'] = df['AIToolCurrently Using'].str.split(';')
    df = df.explode('AIToolCurrently Using')
    # Strip any potential leading/trailing whitespace after splitting
    df['AIToolCurrently Using'] = df['AIToolCurrently Using'].str.strip()


#Count the occurrences of each AI tools
# value_counts() is the simplest way to count unique values in a Series
aitools_counts = df['AIToolCurrently Using'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_aitools = aitools_counts.head(top_n)

#create pie chart
labels = top_aitools.index
sizes = top_aitools.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Admired Language')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
#Check unique value
print('\nThere are', df['WebframeWantToWorkWith'].nunique(), 'unique WebframeWantToWorkWith values in the survey:')
print(df['WebframeWantToWorkWith'].value_counts())
# Out:
# There are 11654 unique WebframeWantToWorkWith values in the survey:
# WebframeWantToWorkWith
# React                                                                 7495
# Spring Boot                                                           5931
# Node.js                                                               5187
# Next.js;Node.js;React                                                 4842
# Node.js;React                                                         4519
#                                                                       ...
# Angular;Astro;Express;Htmx;Node.js;Svelte                                1
# Deno;jQuery;Next.js;Nuxt.js;React;Ruby on Rails;Spring Boot;Vue.js       1
# Django;Express;Spring Boot                                               1
# AngularJS;Django;jQuery;Ruby on Rails                                    1
# NestJS;Nuxt.js                                                           1
# Name: count, Length: 11654, dtype: int64

# %%
#If the data is collected as semi-colon separated strings in a single column,
#Split and explode the entries first to count webframe.
#Example if entries look like: 'Next.js;Node.js;React '
if df['WebframeWantToWorkWith'].dtype == 'object' and df['WebframeWantToWorkWith'].str.contains(';').any():
    df['WebframeWantToWorkWith'] = df['WebframeWantToWorkWith'].str.split(';')
    df = df.explode('WebframeWantToWorkWith')
    # Strip any potential leading/trailing whitespace after splitting
    df['WebframeWantToWorkWith'] = df['WebframeWantToWorkWith'].str.strip()


#Count the occurrences of each AI tools
# value_counts() is the simplest way to count unique values in a Series
webframe_counts = df['WebframeWantToWorkWith'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_webframe = webframe_counts.head(top_n)

#create pie chart
labels = top_webframe.index
sizes = top_webframe.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Used Webframe')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
#Check unique value
print('\nThere are', df['EmbeddedWantToWorkWith'].nunique(), 'unique EmbeddedWantToWorkWith values in the survey:')
print(df['EmbeddedWantToWorkWith'].value_counts())
# Out:
# There are 1471 unique EmbeddedWantToWorkWith values in the survey:
# EmbeddedWantToWorkWith
# Rasberry Pi                                                     8707
# Arduino;Rasberry Pi                                             6967
# Cargo                                                           2668
# Arduino                                                         2319
# GNU GCC                                                         1182
#                                                                 ...
# CMake;Cargo;SCons                                                  1
# Arduino;Boost.Test;CMake;GNU GCC;LLVM's Clang;MSVC;QMake           1
# Boost.Test;Catch2;CMake;LLVM's Clang;Ninja;Rasberry Pi             1
# Boost.Test;CMake;GNU GCC;LLVM's Clang;MSVC;Ninja;Rasberry Pi       1
# cppunit;GNU GCC;Meson;Ninja                                        1
# Name: count, Length: 1471, dtype: int64

# %%
#If the data is collected as semi-colon separated strings in a single column,
#Split and explode the entries first to count embedded.
#Example if entries look like: 'CMake;Cargo;SCons'
if df['EmbeddedWantToWorkWith'].dtype == 'object' and df['EmbeddedWantToWorkWith'].str.contains(';').any():
    df['EmbeddedWantToWorkWith'] = df['EmbeddedWantToWorkWith'].str.split(';')
    df = df.explode('EmbeddedWantToWorkWith')
    # Strip any potential leading/trailing whitespace after splitting
    df['EmbeddedWantToWorkWith'] = df['EmbeddedWantToWorkWith'].str.strip()


#Count the occurrences of each AI tools
# value_counts() is the simplest way to count unique values in a Series
embedded_counts = df['EmbeddedWantToWorkWith'].value_counts()

#Optional: Select the top N databases for clarity
top_n = 5
top_embedded = embedded_counts.head(top_n)

#create pie chart
labels = top_embedded.index
sizes = top_embedded.values

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title(f'Top {top_n} Most Used Embedded')
plt.legend(labels=labels, loc="lower left", title="Categories") 
plt.axis('equal') # Ensures the pie chart is circular
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
